# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.read_csv("/content/iris.csv")
df=pd.DataFrame(data)
print(data)
# Out:
#      150    4  setosa  versicolor  virginica
# 0    5.1  3.5     1.4         0.2          0
# 1    4.9  3.0     1.4         0.2          0
# 2    4.7  3.2     1.3         0.2          0
# 3    4.6  3.1     1.5         0.2          0
# 4    5.0  3.6     1.4         0.2          0
# ..   ...  ...     ...         ...        ...
# 145  6.7  3.0     5.2         2.3          2
# 146  6.3  2.5     5.0         1.9          2
# 147  6.5  3.0     5.2         2.0          2
# 148  6.2  3.4     5.4         2.3          2
# 149  5.9  3.0     5.1         1.8          2
#
# [150 rows x 5 columns]

# %%
print(data.columns)
# Out:
# Index(['150', '4', 'setosa', 'versicolor', 'virginica'], dtype='object')

# %%
print(data.values)
# Out:
# [[5.1 3.5 1.4 0.2 0. ]
#  [4.9 3.  1.4 0.2 0. ]
#  [4.7 3.2 1.3 0.2 0. ]
#  [4.6 3.1 1.5 0.2 0. ]
#  [5.  3.6 1.4 0.2 0. ]
#  [5.4 3.9 1.7 0.4 0. ]
#  [4.6 3.4 1.4 0.3 0. ]
#  [5.  3.4 1.5 0.2 0. ]
#  [4.4 2.9 1.4 0.2 0. ]
#  [4.9 3.1 1.5 0.1 0. ]
#  [5.4 3.7 1.5 0.2 0. ]
#  [4.8 3.4 1.6 0.2 0. ]
#  [4.8 3.  1.4 0.1 0. ]
#  [4.3 3.  1.1 0.1 0. ]
#  [5.8 4.  1.2 0.2 0. ]
#  [5.7 4.4 1.5 0.4 0. ]
#  [5.4 3.9 1.3 0.4 0. ]
#  [5.1 3.5 1.4 0.3 0. ]
#  [5.7 3.8 1.7 0.3 0. ]
#  [5.1 3.8 1.5 0.3 0. ]
#  [5.4 3.4 1.7 0.2 0. ]
#  [5.1 3.7 1.5 0.4 0. ]
#  [4.6 3.6 1.  0.2 0. ]
#  [5.1 3.3 1.7 0.5 0. ]
#  [4.8 3.4 1.9 0.2 0. ]
#  [5.  3.  1.6 0.2 0. ]
#  [5.  3.4 1.6 0.4 0. ]
#  [5.2 3.5 1.5 0.2 0. ]
#  [5.2 3.4 1.4 0.2 0. ]
#  [4.7 3.2 1.6 0.2 0. ]
#  [4.8 3.1 1.6 0.2 0. ]
#  [5.4 3.4 1.5 0.4 0. ]
#  [5.2 4.1 1.5 0.1 0. ]
#  [5.5 4.2 1.4 0.2 0. ]
#  [4.9 3.1 1.5 0.2 0. ]
#  [5.  3.2 1.2 0.2 0. ]
#  [5.5 3.5 1.3 0.2 0. ]
#  [4.9 3.6 1.4 0.1 0. ]
#  [4.4 3.  1.3 0.2 0. ]
#  [5.1 3.4 1.5 0.2 0. ]
# ...

# %%
print(data.columns.values)
# Out:
# ['150' '4' 'setosa' 'versicolor' 'virginica']

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   150         150 non-null    float64
#  1   4           150 non-null    float64
#  2   setosa      150 non-null    float64
#  3   versicolor  150 non-null    float64
#  4   virginica   150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB
# None

# %%
print(data.describe())
# Out:
#               150           4      setosa  versicolor   virginica
# count  150.000000  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.057333    3.758000    1.199333    1.000000
# std      0.828066    0.435866    1.765298    0.762238    0.819232
# min      4.300000    2.000000    1.000000    0.100000    0.000000
# 25%      5.100000    2.800000    1.600000    0.300000    0.000000
# 50%      5.800000    3.000000    4.350000    1.300000    1.000000
# 75%      6.400000    3.300000    5.100000    1.800000    2.000000
# max      7.900000    4.400000    6.900000    2.500000    2.000000

# %%
print(data.head(5))
# Out:
#    150    4  setosa  versicolor  virginica
# 0  5.1  3.5     1.4         0.2          0
# 1  4.9  3.0     1.4         0.2          0
# 2  4.7  3.2     1.3         0.2          0
# 3  4.6  3.1     1.5         0.2          0
# 4  5.0  3.6     1.4         0.2          0

# %%
print(data.tail(8))
# Out:
#      150    4  setosa  versicolor  virginica
# 142  5.8  2.7     5.1         1.9          2
# 143  6.8  3.2     5.9         2.3          2
# 144  6.7  3.3     5.7         2.5          2
# 145  6.7  3.0     5.2         2.3          2
# 146  6.3  2.5     5.0         1.9          2
# 147  6.5  3.0     5.2         2.0          2
# 148  6.2  3.4     5.4         2.3          2
# 149  5.9  3.0     5.1         1.8          2

# %%
print(data[20:40])
# Out:
#     150    4  setosa  versicolor  virginica
# 20  5.4  3.4     1.7         0.2          0
# 21  5.1  3.7     1.5         0.4          0
# 22  4.6  3.6     1.0         0.2          0
# 23  5.1  3.3     1.7         0.5          0
# 24  4.8  3.4     1.9         0.2          0
# 25  5.0  3.0     1.6         0.2          0
# 26  5.0  3.4     1.6         0.4          0
# 27  5.2  3.5     1.5         0.2          0
# 28  5.2  3.4     1.4         0.2          0
# 29  4.7  3.2     1.6         0.2          0
# 30  4.8  3.1     1.6         0.2          0
# 31  5.4  3.4     1.5         0.4          0
# 32  5.2  4.1     1.5         0.1          0
# 33  5.5  4.2     1.4         0.2          0
# 34  4.9  3.1     1.5         0.2          0
# 35  5.0  3.2     1.2         0.2          0
# 36  5.5  3.5     1.3         0.2          0
# 37  4.9  3.6     1.4         0.1          0
# 38  4.4  3.0     1.3         0.2          0
# 39  5.1  3.4     1.5         0.2          0

# %%
print(data[20:40])
# Out:
#     150    4  setosa  versicolor  virginica
# 20  5.4  3.4     1.7         0.2          0
# 21  5.1  3.7     1.5         0.4          0
# 22  4.6  3.6     1.0         0.2          0
# 23  5.1  3.3     1.7         0.5          0
# 24  4.8  3.4     1.9         0.2          0
# 25  5.0  3.0     1.6         0.2          0
# 26  5.0  3.4     1.6         0.4          0
# 27  5.2  3.5     1.5         0.2          0
# 28  5.2  3.4     1.4         0.2          0
# 29  4.7  3.2     1.6         0.2          0
# 30  4.8  3.1     1.6         0.2          0
# 31  5.4  3.4     1.5         0.4          0
# 32  5.2  4.1     1.5         0.1          0
# 33  5.5  4.2     1.4         0.2          0
# 34  4.9  3.1     1.5         0.2          0
# 35  5.0  3.2     1.2         0.2          0
# 36  5.5  3.5     1.3         0.2          0
# 37  4.9  3.6     1.4         0.1          0
# 38  4.4  3.0     1.3         0.2          0
# 39  5.1  3.4     1.5         0.2          0

# %%
print(data.shape)
# Out:
# (150, 5)

# %%
print(data.shape)
# Out:
# (150, 5)

# %%
print(data.loc[[0],["150"]])
# Out:
#    150
# 0  5.1

# %%
print(data.iloc[0,4])
# Out:
# 0

# %%
print(data.loc[[0,1]])
# Out:
#    150    4  setosa  versicolor  virginica
# 0  5.1  3.5     1.4         0.2          0
# 1  4.9  3.0     1.4         0.2          0

# %%
print(data["setosa"].mean())
# Out:
# 3.7580000000000005

# %%
print(data["setosa"].median())
# Out:
# 4.35

# %%
print(data["setosa"].mode()[0])
# Out:
# 1.4

# %%
print(data["setosa"].max())
# Out:
# 6.9

# %%
print(data["setosa"].min())
# Out:
# 1.0

# %%
print(data.groupby(["setosa","4"]).sum())
# Out:
#             150  versicolor  virginica
# setosa 4
# 1.0    3.6  4.6         0.2          0
# 1.1    3.0  4.3         0.1          0
# 1.2    3.2  5.0         0.2          0
#        4.0  5.8         0.2          0
# 1.3    2.3  4.5         0.3          0
# ...         ...         ...        ...
# 6.4    3.8  7.9         2.0          2
# 6.6    3.0  7.6         2.1          2
# 6.7    2.8  7.7         2.0          2
#        3.8  7.7         2.2          2
# 6.9    2.6  7.7         2.3          2
#
# [122 rows x 3 columns]

# %%
print(data.isnull())
# Out:
#        150      4  setosa  versicolor  virginica
# 0    False  False   False       False      False
# 1    False  False   False       False      False
# 2    False  False   False       False      False
# 3    False  False   False       False      False
# 4    False  False   False       False      False
# ..     ...    ...     ...         ...        ...
# 145  False  False   False       False      False
# 146  False  False   False       False      False
# 147  False  False   False       False      False
# 148  False  False   False       False      False
# 149  False  False   False       False      False
#
# [150 rows x 5 columns]

# %%
print(data.isnull().sum())
# Out:
# 150           0
# 4             0
# setosa        0
# versicolor    0
# virginica     0
# dtype: int64

# %%
print(data["setosa"].corr(data["4"]))
# Out:
# -0.4284401043305395

# %%
print(df.dropna())
df.fillna(10,inplace=True)
print(df)
# Out:
#      150    4  setosa  versicolor  virginica
# 0    5.1  3.5     1.4         0.2          0
# 1    4.9  3.0     1.4         0.2          0
# 2    4.7  3.2     1.3         0.2          0
# 3    4.6  3.1     1.5         0.2          0
# 4    5.0  3.6     1.4         0.2          0
# ..   ...  ...     ...         ...        ...
# 145  6.7  3.0     5.2         2.3          2
# 146  6.3  2.5     5.0         1.9          2
# 147  6.5  3.0     5.2         2.0          2
# 148  6.2  3.4     5.4         2.3          2
# 149  5.9  3.0     5.1         1.8          2
#
# [150 rows x 5 columns]
#      150    4  setosa  versicolor  virginica
# 0    5.1  3.5     1.4         0.2          0
# 1    4.9  3.0     1.4         0.2          0
# 2    4.7  3.2     1.3         0.2          0
# 3    4.6  3.1     1.5         0.2          0
# 4    5.0  3.6     1.4         0.2          0
# ..   ...  ...     ...         ...        ...
# 145  6.7  3.0     5.2         2.3          2
# ...

# %%
 sns.pairplot(data=data)
plt.show()

# %%
sns.boxplot(data=data,x='setosa')
plt.show()

# %%
corr = data[["setosa","4"]].corr()
sns.heatmap(corr)
plt.show()

# %%
sns.barplot(data=data['setosa'])
# Out:
# <Axes: ylabel='setosa'>

# %%
sns.histplot(data=data["setosa"])
# Out:
# <Axes: xlabel='setosa', ylabel='Count'>

# %%
sns.displot(data["setosa"], bins=10, kde=True)

# %%
sns.scatterplot(x="setosa",y="versicolor",data=data)
plt.show()
